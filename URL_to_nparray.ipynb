# %%
#pip install dill

# %%
import numpy as np
import pandas as pd

import dill

from google.colab import drive, files
from PIL import Image
from urllib.request import urlopen

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-508330c2-6081-412f-9848-cfdb736555cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-508330c2-6081-412f-9848-cfdb736555cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Books.csv to Books (1).csv

# %%
df = pd.read_csv('Books.csv')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#               ISBN                                         Book-Title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %%
df["Image-URL-S"] = range(10000)
df["Image-URL-S"] = df["Image-URL-S"].astype(object)
df
# Out:
#               ISBN                                         Book-Title  \
# 43      0061099686                                           Downtown
# 131     9724119378                         O Deus Das Pequenas Coisas
# 209     0345433173                                The Tall Pine Polka
# 299     1563898586      The League of Extraordinary Gentlemen, Vol. 1
# 323     0380728729                                           Babyhood
# ...            ...                                                ...
# 271189  0425127486  Hardshell (Originally Published As Night Visio...
# 271192  0394727959                The Wine of Astonishment (Aventura)
# 271261  0310232546   Ask Lily (Young Women of Faith: Lily Series, ...
# 271279  1562477900                      Amelia Hits the Road (Amelia)
# 271281  1584853301                            Oh Boy, Amelia (Amelia)
#
#                 Book-Author Year-Of-Publication  \
# 43      Anne Rivers Siddons                1995
# ...

# %%
import random
rnd = random.sample(range(0,271360), 261360)
len(rnd)
# Out:
# 261360

# %%
df = df.drop(labels=rnd, axis = 0)

# %%
df
# Out:
#               ISBN                                         Book-Title  \
# 43      0061099686                                           Downtown
# 131     9724119378                         O Deus Das Pequenas Coisas
# 209     0345433173                                The Tall Pine Polka
# 299     1563898586      The League of Extraordinary Gentlemen, Vol. 1
# 323     0380728729                                           Babyhood
# ...            ...                                                ...
# 271189  0425127486  Hardshell (Originally Published As Night Visio...
# 271192  0394727959                The Wine of Astonishment (Aventura)
# 271261  0310232546   Ask Lily (Young Women of Faith: Lily Series, ...
# 271279  1562477900                      Amelia Hits the Road (Amelia)
# 271281  1584853301                            Oh Boy, Amelia (Amelia)
#
#                 Book-Author Year-Of-Publication  \
# 43      Anne Rivers Siddons                1995
# ...

# %%
for i in range(len(df['Image-URL-S'])):
  try:
    df["Image-URL-S"].iloc[i] = np.asarray(Image.open(urlopen(df["Image-URL-M"].iloc[i])))
  except:
    print(i)
# Out:
# 750
# 1524
# 1836
# 6163
# 8730
# 9606

# %%
df
# Out:
#               ISBN                                         Book-Title  \
# 43      0061099686                                           Downtown
# 131     9724119378                         O Deus Das Pequenas Coisas
# 209     0345433173                                The Tall Pine Polka
# 299     1563898586      The League of Extraordinary Gentlemen, Vol. 1
# 323     0380728729                                           Babyhood
# ...            ...                                                ...
# 271189  0425127486  Hardshell (Originally Published As Night Visio...
# 271192  0394727959                The Wine of Astonishment (Aventura)
# 271261  0310232546   Ask Lily (Young Women of Faith: Lily Series, ...
# 271279  1562477900                      Amelia Hits the Road (Amelia)
# 271281  1584853301                            Oh Boy, Amelia (Amelia)
#
#                 Book-Author Year-Of-Publication  \
# 43      Anne Rivers Siddons                1995
# ...

# %%
drive.mount('/content/drive')
filepath = '/content/drive/My Drive/MLkurzus/Beadandó/session.pkl'
dill.dump_session(filepath) # Save the session
# Out:
# Mounted at /content/drive
